# %% [markdown]
# <a href="https://colab.research.google.com/github/vipashaaV321/3D-Datavisualization/blob/main/Item_Item_MF_SVD_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse.linalg import svds
from surprise import Dataset
from surprise import Reader
from surprise import SVD
from surprise import accuracy
from surprise.model_selection import train_test_split

# %% [markdown]
# ### Item - Item collaborative filtering with Matrix factorization

# %% [markdown]
# #### SVD with surprise library

# %% [markdown]
# #### Load google drive and define base path

# %%
Base_path ='/content/drive/MyDrive/Data/RS2'

# %%
# !pip install surprise

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### Load Filtered data and applying operations using surprise library

# %%
# Load dataset
df = pd.read_csv(Base_path+"/short-recipes-20.csv")

# %%
# Define Reader
reader = Reader(rating_scale=(1, 5))

# %%
# Load data into Surprise dataset
data = Dataset.load_from_df(df[['user_id', 'recipe_id', 'rating']], reader)

# %%
# Split dataset into training and testing sets
trainset, testset = train_test_split(data, test_size=0.2)

# %%
testset
# Out:
# [(962690, 335810, 5.0),
#  (587766, 238889, 4.0),
#  (394085, 208118, 4.0),
#  (362983, 212706, 5.0),
#  (220348, 171450, 5.0),
#  (508949, 125282, 5.0),
#  (237123, 157676, 5.0),
#  (121690, 210693, 5.0),
#  (154026, 65909, 4.0),
#  (344087, 86593, 5.0),
#  (174096, 219072, 5.0),
#  (593927, 71846, 5.0),
#  (383346, 243431, 5.0),
#  (797706, 36359, 5.0),
#  (55578, 60402, 5.0),
#  (209603, 167693, 5.0),
#  (424680, 286053, 5.0),
#  (55380, 38261, 4.0),
#  (653438, 287499, 4.0),
#  (176615, 61591, 5.0),
#  (41409, 68408, 5.0),
#  (704950, 311778, 5.0),
#  (212609, 428645, 5.0),
#  (494867, 96865, 5.0),
#  (461834, 463701, 5.0),
#  (245408, 24476, 5.0),
#  (281701, 137135, 5.0),
#  (377039, 52366, 4.0),
#  (465056, 158420, 4.0),
#  (39301, 38673, 5.0),
#  (783601, 16371, 4.0),
#  (305531, 174291, 5.0),
#  (926169, 181223, 5.0),
#  (212609, 468451, 5.0),
#  (463435, 450133, 5.0),
#  (37449, 485107, 5.0),
#  (424680, 88521, 5.0),
#  (498271, 298097, 5.0),
#  (383346, 297379, 5.0),
#  (74652, 129615, 5.0),
#  (798181, 105136, 5.0),
#  (47892, 341569, 5.0),
#  (288218, 116412, 5.0),
#  (121690, 203294, 5.0),
#  (286566, 320417, 5.0),
#  (233583, 378866, 5.0),
#  (17803, 121588, 4.0),
#  (804550, 486707, 5.0),
#  (141293, 279724, 5.0),
#  (1211187, 5170, 4.0),
#  (118268, 128746, 4.0),
#  (542159, 296407, 5.0),
#  (227978, 418327, 5.0),
#  (209441, 312650, 5.0),
#  (74652, 128746, 5.0),
#  (280271, 481960, 5.0),
#  (1535, 16632, 5.0),
#  (47892, 532740, 5.0),
#  (379033, 174610, 5.0),
#  (223979, 279907, 5.0),
#  (191533, 135646, 5.0),
#  (706608, 118761, 4.0),
#  (223979, 96003, 5.0),
#  (407007, 166250, 5.0),
#  (6357, 20934, 0.0),
#  (139381, 86309, 5.0),
#  (679953, 274370, 5.0),
#  (330545, 351313, 4.0),
#  (96796, 369943, 5.0),
#  (184530, 142884, 5.0),
#  (324677, 182870, 5.0),
#  (56680, 25423, 5.0),
#  (49304, 92502, 5.0),
#  (1072593, 463518, 5.0),
#  (106624, 234235, 5.0),
#  (496803, 304851, 5.0),
#  (318235, 99746, 4.0),
#  (537937, 302815, 5.0),
#  (1072593, 448067, 5.0),
#  (80353, 165874, 5.0),
#  (1179225, 400814, 5.0),
#  (131126, 479001, 5.0),
#  (324621, 117412, 4.0),
#  (64154, 25774, 5.0),
#  (65502, 457987, 5.0),
#  (15521, 441132, 5.0),
#  (47510, 302791, 5.0),
#  (383346, 440382, 5.0),
#  (465911, 252005, 5.0),
#  (253407, 162783, 4.0),
#  (383346, 367708, 5.0),
#  (54678, 98724, 5.0),
#  (150281, 424269, 5.0),
#  (115853, 26442, 5.0),
#  (34025, 96923, 5.0),
#  (174096, 424892, 5.0),
#  (209747, 325174, 5.0),
#  (133174, 290945, 4.0),
#  (527607, 44519, 5.0),
#  (80353, 276671, 5.0),
#  (59064, 74282, 5.0),
#  (67656, 310837, 4.0),
#  (424680, 341466, 5.0),
#  (88099, 505734, 5.0),
#  (593927, 423618, 5.0),
#  (133174, 170285, 5.0),
#  (953275, 423696, 5.0),
#  (77458, 69501, 4.0),
#  (839492, 23966, 0.0),
#  (47892, 162122, 5.0),
#  (242766, 223152, 5.0),
#  (222564, 146439, 5.0),
#  (29196, 177343, 5.0),
#  (286209, 181774, 4.0),
#  (590105, 15196, 5.0),
#  (427184, 241567, 5.0),
#  (199848, 82816, 5.0),
#  (353579, 234834, 5.0),
#  (333017, 171661, 2.0),
#  (88099, 140898, 5.0),
#  (59780, 89051, 5.0),
#  (537937, 31188, 5.0),
#  (953275, 184232, 5.0),
#  (60989, 51811, 4.0),
#  (841895, 76491, 5.0),
#  (58104, 209672, 5.0),
#  (135566, 318755, 5.0),
#  (242766, 66976, 5.0),
#  (79877, 231636, 5.0),
#  (324621, 169770, 4.0),
#  (83093, 192001, 5.0),
#  (520150, 217183, 4.0),
#  (96177, 117817, 5.0),
#  (171790, 296176, 5.0),
#  (222564, 51265, 5.0),
#  (464080, 116030, 5.0),
#  (537937, 165409, 5.0),
#  (141610, 126188, 4.0),
#  (50509, 278015, 3.0),
#  (222564, 251188, 5.0),
#  (452576, 211692, 4.0),
#  (4470, 38205, 5.0),
#  (677508, 106515, 5.0),
#  (632249, 156635, 4.0),
#  (655199, 96715, 2.0),
#  (122235, 51040, 5.0),
#  (570804, 374201, 0.0),
#  (203013, 352308, 5.0),
#  ...]

# %%
# Create SVD model and fit on training set
model = SVD()
model.fit(trainset)

# %%
# Make predictions on test set
predictions = model.test(testset)

# %%
# Calculate RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.7849
# 0.7848683468811428

# %% [markdown]
# ##### Recommendations

# %%
# Recommend top 10 items for user 1
user_id = 1588
recipes_to_ignore = df[df['user_id'] == user_id]['recipe_id'].tolist()
recipes = df[~df['recipe_id'].isin(recipes_to_ignore)]['recipe_id'].unique()
predictions = [(iid, model.predict(user_id, iid).est) for iid in recipes]
top_recipes = sorted(predictions, key=lambda x: x[1], reverse=True)[:10]
print(top_recipes)
# Out:
# [(55309, 5), (107440, 5), (107059, 5), (295676, 4.9897461448833305), (28026, 4.98394272559119), (57591, 4.978667763447991), (53194, 4.972504815696459), (77497, 4.969154672315901), (186029, 4.966219103177965), (29084, 4.964935436567342)]

# %%
type(top_recipes)
# Out:
# list

# %%
df2=pd.DataFrame(top_recipes,columns =['recipe_id','avg_rating'])

# %%
df2
# Out:
#    recipe_id  avg_rating
# 0      55309    5.000000
# 1     107440    5.000000
# 2     107059    5.000000
# 3     295676    4.989746
# 4      28026    4.983943
# 5      57591    4.978668
# 6      53194    4.972505
# 7      77497    4.969155
# 8     186029    4.966219
# 9      29084    4.964935

# %%
# recommendation = df2.join(df, on='recipe_id')

# %% [markdown]
# ## SVD with Numpy

# %%
# Load dataset
df = pd.read_csv(Base_path+"/short-recipes-20.csv")

# %%
df
# Out:
#         Unnamed: 0                                        name  user_id  \
# 0               21                     calm your nerves  tonic    65056
# 1               76         homemade  vegetable soup from a can   189616
# 2               77         homemade  vegetable soup from a can   369715
# 3              170  i stole the idea from mirj  sesame noodles    49304
# 4              171  i stole the idea from mirj  sesame noodles    82648
# ...            ...                                         ...      ...
# 122605      698886           zwiebeln salat  swiss onion salad   169430
# 122606      698890                          zydeco green beans   283251
# 122607      698891                                zydeco salad   226863
# 122608      698892                                zydeco salad   621626
# 122609      698893                                zydeco sauce   865936
#
#         recipe_id  rating  minutes
# 0           39959     5.0        5
# 1           87098     5.0       12
# 2           87098     4.0       12
# 3           90921     5.0       18
# 4           90921     5.0       18
# ...           ...     ...      ...
# 122605     455209     5.0       10
# 122606     185979     0.0       20
# 122607     367912     5.0        5
# 122608     367912     5.0        5
# 122609     357451     5.0       15
#
# [122610 rows x 6 columns]

# %%
# Calculate the mean rating for each recipe
mean_ratings = pd.DataFrame(df.groupby('name')['rating'].mean())

# %%
# Add a column for the number of ratings for each recipe
mean_ratings['num_ratings'] = df.groupby('name')['rating'].count()

# %%
mean_ratings
# Out:
#                                           rating  num_ratings
# name
# 007  martini                                 5.0            1
# 1 2 3 black bean salsa dip                   5.0            5
# 1 2 3 rice and chili burritos                4.0            1
# 1 dish caramel pecan coffee cake  round      5.0            1
# 1 gram fat chocolate banana freezer pops     4.0            1
# ...                                          ...          ...
# zwieback                                     5.0            1
# zwiebeln salat  swiss onion salad            5.0            1
# zydeco green beans                           0.0            1
# zydeco salad                                 5.0            2
# zydeco sauce                                 5.0            1
#
# [38592 rows x 2 columns]

# %%
# Pivot the data to create a recipe-rating matrix
recipe_ratings = df.pivot_table(index='name', columns='user_id', values='rating').fillna(0)

# %%
recipe_ratings
# Out:
# user_id                                   1533        1535        1634        \
# name
# 007  martini                                     0.0         0.0         0.0
# 1 2 3 black bean salsa dip                       0.0         0.0         0.0
# 1 2 3 rice and chili burritos                    0.0         0.0         0.0
# 1 dish caramel pecan coffee cake  round          0.0         0.0         0.0
# 1 gram fat chocolate banana freezer pops         0.0         0.0         0.0
# ...                                              ...         ...         ...
# zwieback                                         0.0         0.0         0.0
# zwiebeln salat  swiss onion salad                0.0         0.0         0.0
# zydeco green beans                               0.0         0.0         0.0
# zydeco salad                                     0.0         0.0         0.0
# zydeco sauce                                     0.0         0.0         0.0
#
# user_id                                   2310        2312        3205        \
# name
# 007  martini                                     0.0         0.0         0.0
# 1 2 3 black bean salsa dip                       0.0         0.0         0.0
# 1 2 3 rice and chili burritos                    0.0         0.0         0.0
# 1 dish caramel pecan coffee cake  round          0.0         0.0         0.0
# 1 gram fat chocolate banana freezer pops         0.0         0.0         0.0
# ...                                              ...         ...         ...
# zwieback                                         0.0         0.0         0.0
# zwiebeln salat  swiss onion salad                0.0         0.0         0.0
# zydeco green beans                               0.0         0.0         0.0
# zydeco salad                                     0.0         0.0         0.0
# zydeco sauce                                     0.0         0.0         0.0
#
# user_id                                   3288        4291        4439        \
# name
# 007  martini                                     0.0         0.0         0.0
# 1 2 3 black bean salsa dip                       0.0         0.0         0.0
# 1 2 3 rice and chili burritos                    0.0         0.0         0.0
# 1 dish caramel pecan coffee cake  round          0.0         0.0         0.0
# 1 gram fat chocolate banana freezer pops         0.0         0.0         0.0
# ...                                              ...         ...         ...
# zwieback                                         0.0         0.0         0.0
# zwiebeln salat  swiss onion salad                0.0         0.0         0.0
# zydeco green beans                               0.0         0.0         0.0
# zydeco salad                                     0.0         0.0         0.0
# zydeco sauce                                     0.0         0.0         0.0
#
# user_id                                   4470        ...  2324285     \
# name                                                  ...
# 007  martini                                     0.0  ...         0.0
# 1 2 3 black bean salsa dip                       0.0  ...         0.0
# 1 2 3 rice and chili burritos                    0.0  ...         0.0
# 1 dish caramel pecan coffee cake  round          0.0  ...         0.0
# 1 gram fat chocolate banana freezer pops         0.0  ...         0.0
# ...                                              ...  ...         ...
# zwieback                                         0.0  ...         0.0
# zwiebeln salat  swiss onion salad                0.0  ...         0.0
# zydeco green beans                               0.0  ...         0.0
# zydeco salad                                     0.0  ...         0.0
# zydeco sauce                                     0.0  ...         0.0
#
# user_id                                   2399085     2549237     2585084     \
# name
# 007  martini                                     0.0         0.0         0.0
# 1 2 3 black bean salsa dip                       0.0         0.0         0.0
# 1 2 3 rice and chili burritos                    0.0         0.0         0.0
# 1 dish caramel pecan coffee cake  round          0.0         0.0         0.0
# 1 gram fat chocolate banana freezer pops         0.0         0.0         0.0
# ...                                              ...         ...         ...
# zwieback                                         0.0         0.0         0.0
# zwiebeln salat  swiss onion salad                0.0         0.0         0.0
# zydeco green beans                               0.0         0.0         0.0
# zydeco salad                                     0.0         0.0         0.0
# zydeco sauce                                     0.0         0.0         0.0
#
# user_id                                   2597942     1800054678  1802849661  \
# name
# 007  martini                                     0.0         0.0         0.0
# 1 2 3 black bean salsa dip                       0.0         0.0         0.0
# 1 2 3 rice and chili burritos                    0.0         0.0         0.0
# 1 dish caramel pecan coffee cake  round          0.0         0.0         0.0
# 1 gram fat chocolate banana freezer pops         0.0         0.0         0.0
# ...                                              ...         ...         ...
# zwieback                                         0.0         0.0         0.0
# zwiebeln salat  swiss onion salad                0.0         0.0         0.0
# zydeco green beans                               0.0         0.0         0.0
# zydeco salad                                     0.0         0.0         0.0
# zydeco sauce                                     0.0         0.0         0.0
#
# user_id                                   2000431901  2000498330  2001102678
# name
# 007  martini                                     0.0         0.0         0.0
# 1 2 3 black bean salsa dip                       0.0         0.0         0.0
# 1 2 3 rice and chili burritos                    0.0         4.0         0.0
# 1 dish caramel pecan coffee cake  round          0.0         0.0         0.0
# 1 gram fat chocolate banana freezer pops         0.0         0.0         0.0
# ...                                              ...         ...         ...
# zwieback                                         0.0         0.0         0.0
# zwiebeln salat  swiss onion salad                0.0         0.0         0.0
# zydeco green beans                               0.0         0.0         0.0
# zydeco salad                                     0.0         0.0         0.0
# zydeco sauce                                     0.0         0.0         0.0
#
# [38592 rows x 1706 columns]

# %%
# Perform SVD on the normalized ratings matrix
## Normalize the ratings by subtracting the mean rating from each rating
#normalized_ratings = recipe_ratings - np.array(mean_ratings['rating'])
# U, sigma, Vt = svds(normalized_ratings, k=50)

from scipy.sparse.linalg import svds

U, sigma, Vt = svds(recipe_ratings, k=50)

sigma = np.diag(sigma)

# %%
sigma
# Out:
# array([[ 92.68204202,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [  0.        ,  93.11030595,   0.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [  0.        ,   0.        ,  93.76309312, ...,   0.        ,
#           0.        ,   0.        ],
#        ...,
#        [  0.        ,   0.        ,   0.        , ..., 200.21737402,
#           0.        ,   0.        ],
#        [  0.        ,   0.        ,   0.        , ...,   0.        ,
#         206.07067749,   0.        ],
#        [  0.        ,   0.        ,   0.        , ...,   0.        ,
#           0.        , 266.81389711]])

# %%
# Reconstruct the ratings matrix from the SVD components
predicted_ratings = np.dot(np.dot(U, sigma), Vt) + np.array(mean_ratings['rating']).reshape(-1, 1)

# %%
predicted_ratings
# Out:
# array([[4.9993916 , 4.99671492, 4.9991719 , ..., 5.00262075, 4.99895158,
#         5.00182653],
#        [5.00426398, 5.05444877, 5.00883362, ..., 5.01878373, 5.00153308,
#         5.01071769],
#        [4.00010497, 4.00143942, 4.00008833, ..., 4.00013253, 4.00068193,
#         4.00021818],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [5.00021097, 4.97002797, 4.99819336, ..., 5.00242443, 5.00128009,
#         4.99007471],
#        [5.00018362, 4.99819334, 4.99990741, ..., 5.00130859, 5.00014713,
#         4.99830278]])

# %%
# Convert the predicted ratings array to a DataFrame
predicted_ratings_df = pd.DataFrame(predicted_ratings, index=recipe_ratings.index, columns=recipe_ratings.columns)

# %%
# Define a function to get the top N recommendations for a user
def get_top_n(user_id, n=10):
    # Get the user's ratings
    user_ratings = df[df['user_id'] == user_id][['name', 'rating']]
    # Merge with the predicted ratings
    user_ratings = user_ratings.join(predicted_ratings_df, on='name')
    # Sort by the predicted rating and select the top N
    top_n = user_ratings.sort_values(by=user_id, ascending=False).head(n)
    return top_n

# %%
# Test the recommendation function with a sample user
get_top_n(1533, 10)['name']
# Out:
# 69715                                    margarita parfaits
# 69030     mandarin tossed chicken salad with cashew dres...
# 10406                                   basil garlic butter
# 18791                              californian apple crunch
# 29882                           costa rican marinated mango
# 29883                          costa rican stuffed tortilla
# 102278                     spicy banana fritters  zitumbuwa
# 84080                               peggy s cheese savories
# 58799            indecent breasts with noodles or wild rice
# 27166                                   cinnamon roll toast
# Name: name, dtype: object
